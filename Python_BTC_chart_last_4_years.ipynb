# %%
import pandas as pd
import yfinance as yf

# Завантаження даних про біткоїн
btc_data = yf.download('BTC-USD', start='2020-01-01', end='2024-07-01')

# Вибір колонок "Date" та "Close" (ціна закриття)
btc_data = btc_data[['Close']].copy()
btc_data.reset_index(inplace=True)
btc_data.rename(columns={'Close': 'Price', 'Date': 'Date'}, inplace=True)

# Збереження у форматі CSV
btc_data.to_csv('btc_price_data.csv', index=False)

print(btc_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date        Price
# 0 2020-01-01  7200.174316
# 1 2020-01-02  6985.470215
# 2 2020-01-03  7344.884277
# 3 2020-01-04  7410.656738
# 4 2020-01-05  7411.317383

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
btc_data = pd.read_csv('btc_price_data.csv', parse_dates=['Date'])

# %%
plt.figure(figsize=(12, 6))
plt.plot(btc_data['Date'], btc_data['Price'], marker='o', linestyle='-', color='b', label='Bitcoin Price')
plt.title('Bitcoin Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
